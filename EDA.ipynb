# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# 1. Load Datasets
#
# 2. Cleam data (missing values, duplicates, types)
#
# 3. Treat outliners
#
# 4. Univariate & bivariate and multivariate analysis
#
# 5. Insights

# %% [markdown]
# ### Outlier - A data point that is significantly different from other observations in a dataset.
#
# #### How outliers will come?
# 1. Measurement errors
# 2. Data entry mistakes
#
# #### Why they are important?
# 1. They can be errors
# 2. They effect the data analysis
#
# #### How to identify the errors?
#
# 1. Statistcal Methods
#
# --->Interquartile Methods
#
# --->Z-Score
#
# 2. Visualization Techniques
#
# --->Box Plot
#
# --->Scatter Plots
#
# --->Histograms

# %% [markdown]
# ### Univariate analysis - A method that analyzes a single variable to describe its characteristics, find patterns and summarize data.
#
# #### It involves only one variable.
#
# #### Bivariate analysis - it will give the relationship between 2 variables. It helps to find if there is an co-relation, assosiation or conection between the 2 variables.
#
# #### It involves 2 variables (x & y).
#
# #### Multivariate analysis - To understand how multiple factors interact & influence each other.
#
# #### It involves more then 2 variables
#
# Example :
# Hoe our age, income, and education level together influence the purchasing behavior.

# %% [markdown]
# ## ETL

# %% [markdown]
# ## EDA : < Dataset >
#
# 1. Load & Overview
#
# 2. Cleaning (missing, dupes, dtypes)
#
# 3. Uni, Bi, Multi analysis
#
# 4. Outlier - IQR
#
# 5. Feature Engineering
#
# 6. Key Insights

# %% [markdown]
# Feature Engineering - "F.E is the process of tuening raw data into useful features " that helps to improve the preferences of machine learning models

# %% [markdown]
# # 1. Load libraries & Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df =sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# basic information and overview
print("shape of dataset: ",df.shape)
print("\n Data Info: \n")
df.info()

# Summary statistics
df.describe(include='all')
# Out:
# shape of dataset:  (891, 15)
#
#  Data Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
# Missing values analysis

missing= pd.DataFrame({
    'missing_count':df.isnull().sum(),
    'missing_percent':(df.isnull().sum()/len(df))*100
})

missing.sort_values(by='missing_percent',ascending=False)
# Out:
#              missing_count  missing_percent
# deck                   688        77.216611
# age                    177        19.865320
# embarked                 2         0.224467
# embark_town              2         0.224467
# sex                      0         0.000000
# pclass                   0         0.000000
# survived                 0         0.000000
# fare                     0         0.000000
# parch                    0         0.000000
# sibsp                    0         0.000000
# class                    0         0.000000
# adult_male               0         0.000000
# who                      0         0.000000
# alive                    0         0.000000
# alone                    0         0.000000

# %%
#4. Handling Missing Values

# Fill the numeric missing values with the mean
df['age']=df['age'].fillna(df['age'].mean())

# Fill categorical missing values with mode
df['embarked']=df['embarked'].fillna(df['embarked'].mode()[0])

#Drop 'deck' column (too many missing values)
df.drop(columns=['deck'],inplace=True)

print("Missing values after cleaning : \n",df.isnull().sum().sum())
# Out:
# Missing values after cleaning :
#  2

# %%
# Duplicates & Data type check

print("Duplicate rows: ",df.duplicated().sum())

#convert some columns to category type
df['class']= df['class'].astype('category')
df['sex']= df['sex'].astype('category')
df['embarked']= df['embarked'].astype('category')

df.info()


# step 6: Univariate Analysis for numerical features
# Out:
# Duplicate rows:  107
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(4), float64(2), int64(4), object(3)
# memory usage: 68.7+ KB

# %%
# step 6: Univariate Analysis for numerical features
num_cols = df.select_dtypes(include=['float64','int64']).columns
df[num_cols].describe()

#Histogram : Age
sns.histplot(df['age'],bins=30,kde =True ,color='skyblue')
plt.title("Age Distribution of passengers")
plt.show()

#Boxplot : Fare
sns.boxplot(x=df['fare'],color='orange')
plt.title("fare Distribution with outliers")
plt.show()

# %%
# Univariate Analysis - Categorical Features

cat_clos=df.select_dtypes('category').columns

for col in cat_clos:
    sns.catplot(x=col,data=df)
    plt.title(f"count of {col}")
    plt.show()

# %%
# Univariate Analysis - Numerical vs Categorical 

sns.boxplot(x='class',y='fare',data=df)
plt.title("Fare by class")
plt.show()

sns.boxplot(x='sex',y='age',data=df)
plt.title("Fare by gender")
plt.show()

# %%
# corelation and multivariate analysis

corr=df[['age','fare','survived']].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

sns.pairplot(df[['age','fare','survived']],hue='survived')
plt.show()

# %% [markdown]
# Insights:
#
# 1.Fare has a positive correlation with survival
#
# 2.Age shows a slight negative correlation with survival

# %%
# Outluer Detection using IQR
Q1=df['fare'].quantile(0.25)
Q3=df['fare'].quantile(0.75)
IQR=Q3-Q1

lower= Q1-1.5*IQR
upper=Q3+1.5*IQR

outliers=df[(df['fare']<lower)|(df['fare']>upper)]
print("Number of outliers in are fare: ",len(outliers))

# Outliers
df['fare_capped']= df['fare'].clip(lower,upper)
sns.boxplot(x=df['fare_capped'])
plt.title("Fare after outlier capping")
plt.show()
# Out:
# Number of outliers in are fare:  116

# %%
# Feature Engineering

# Create new features

df['family_size']=df['sibsp']+df['parch']+1

df['is_alone']=(df['family_size']==1).astype(int)

sns.countplot(x='is_alone',hue='survived',data=df)
plt.title("survived by alone/Family status")
plt.show()

df[['family_size','is_alone','survived']].head()
# Out:
#    family_size  is_alone  survived
# 0            2         0         0
# 1            2         0         1
# 2            1         1         1
# 3            2         0         1
# 4            1         1         0

# %%
# Export the cleaned data
df.to_csv("Titanic_cleaned.csv",index=False)
print("\n Cleaned Titanic data saved as titanic_cleaned.csv")
# Out:
#  Cleaned Titanic data saved as titanic_cleaned.csv

# %%
import os
print(os.getcwd())
# Out:
# c:\TARUN\Tek Works\data_analysis

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'
